# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ZeeshanAhmedPatell/FlyRank-ML/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# **My lane (or freestyle) and why**
#
# I chose the **CTR / Engagement Opportunity Scoring** lane because improving click-through rate (CTR) can help identify pages that have the greatest opportunity for improvement. By analyzing metrics such as CTR, impressions, search volume, and average position, I aim to identify pages where optimization efforts could have the highest impact. This lane is practical, data-driven, and provides actionable insights for improving website performance.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# **The question: decision, action, cost of a wrong call:**
#
# **Research Question:** Which pages should be prioritized for optimization to improve CTR and user engagement?
#
# **Decision:** Identify pages with the highest opportunity for improvement.
#
# **Action:** A content or SEO team can review these pages, update titles or content, and improve their visibility and relevance.
#
# **Cost of a wrong recommendation:** If low-priority pages are selected instead of high-impact ones, time and resources may be wasted while better opportunities are missed.
#
# **Why ML can help:** Machine learning can combine multiple metrics to rank opportunities more consistently than relying on a single metric alone.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd

df = pd.read_csv("./data/raw/content_refresh_anonymized.csv")

print("Total pages:", len(df))
print("Average CTR:", round(df["ctr"].mean(), 3))
print("Average Position:", round(df["avg_position"].mean(), 2))
# Out:
# Total pages: 30000
# Average CTR: 0.511
# Average Position: 16.34

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# **Careful words: what I can and can't claim**
#
# This project will provide decision-support by identifying patterns and ranking pages based on the available data. Any findings will be presented as observed, measured, and directional rather than as proof of cause and effect. The recommendations are intended to help prioritize optimization opportunities, but they do not guarantee improved rankings or CTR. This project does not predict or explain Google's ranking algorithm, and any recommendations should be validated before implementation.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
